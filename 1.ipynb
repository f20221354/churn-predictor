# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("WA_Fn-UseC_-Telco-Customer-Churn.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df_m=df

# %%
df_m['gender']=df_m['gender'].map({'Female':1,'Male':0})

# %%
df_m['is_female']=df_m['gender']

# %%
df_m=df_m.rename(columns={'gender':'is_female'})

# %%
df_m['Partner'].count()
# Out:
# np.int64(7043)

# %%
df_m.columns[df_m.columns.duplicated()]
# Out:
# Index(['is_female'], dtype='object')

# %%
df_m
# Out:
#       customerID is_female  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG         1              0     Yes         No       1
# 1     5575-GNVDE         0              0      No         No      34
# 2     3668-QPYBK         0              0      No         No       2
# 3     7795-CFOCW         0              0      No         No      45
# 4     9237-HQITU         1              0      No         No       2
# ...          ...       ...            ...     ...        ...     ...
# 7038  6840-RESVB         0              0     Yes        Yes      24
# 7039  2234-XADUH         1              0     Yes        Yes      72
# 7040  4801-JZAZL         1              0     Yes        Yes      11
# 7041  8361-LTMKD         0              1     Yes         No       4
# 7042  3186-AJIEK         0              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# ...

# %%
print(df_m.columns[df_m.columns.duplicated()])
# Out:
# Index(['is_female'], dtype='object')

# %%
df_m
# Out:
#       customerID is_female  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG         1              0     Yes         No       1
# 1     5575-GNVDE         0              0      No         No      34
# 2     3668-QPYBK         0              0      No         No       2
# 3     7795-CFOCW         0              0      No         No      45
# 4     9237-HQITU         1              0      No         No       2
# ...          ...       ...            ...     ...        ...     ...
# 7038  6840-RESVB         0              0     Yes        Yes      24
# 7039  2234-XADUH         1              0     Yes        Yes      72
# 7040  4801-JZAZL         1              0     Yes        Yes      11
# 7041  8361-LTMKD         0              1     Yes         No       4
# 7042  3186-AJIEK         0              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# ...

# %%
df_m = df_m.loc[:, ~df_m.columns.duplicated()]

# %%
df_m
# Out:
#       customerID  is_female  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG          1              0     Yes         No       1
# 1     5575-GNVDE          0              0      No         No      34
# 2     3668-QPYBK          0              0      No         No       2
# 3     7795-CFOCW          0              0      No         No      45
# 4     9237-HQITU          1              0      No         No       2
# ...          ...        ...            ...     ...        ...     ...
# 7038  6840-RESVB          0              0     Yes        Yes      24
# 7039  2234-XADUH          1              0     Yes        Yes      72
# 7040  4801-JZAZL          1              0     Yes        Yes      11
# 7041  8361-LTMKD          0              1     Yes         No       4
# 7042  3186-AJIEK          0              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# ...

# %%
df['Partner'].value_counts()
# Out:
# Partner
# No     3641
# Yes    3402
# Name: count, dtype: int64

# %%
df_m['Partner']=df_m['Partner'].map({'No':1,'Yes':1})
# Out:
# C:\Users\Standby\AppData\Local\Temp\ipykernel_11632\811189281.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_m['Partner']=df_m['Partner'].map({'No':1,'Yes':1})

# %%
df_m=df_m.rename(columns={'Partner':'Partner_No'})

# %%
df_m.head()
# Out:
#    customerID  is_female  SeniorCitizen  Partner_No Dependents  tenure  \
# 0  7590-VHVEG          1              0           1         No       1
# 1  5575-GNVDE          0              0           1         No      34
# 2  3668-QPYBK          0              0           1         No       2
# 3  7795-CFOCW          0              0           1         No      45
# 4  9237-HQITU          1              0           1         No       2
#
#   PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0           No  No phone service             DSL             No  ...
# 1          Yes                No             DSL            Yes  ...
# 2          Yes                No             DSL            Yes  ...
# 3           No  No phone service             DSL            Yes  ...
# 4          Yes                No     Fiber optic             No  ...
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
binary_cols = ['Dependents', 'PhoneService', 'TechSupport', 
               'StreamingTV', 'StreamingMovies', 'PaperlessBilling', 'Churn',]

for col in binary_cols:
    unique_vals = set(df[col].unique())
    if unique_vals <= {'Yes', 'No'}:
        print(f"{col}: OK - only Yes/No -> {unique_vals}")
    else:
        print(f"{col}: WARNING - extra values found -> {unique_vals}")
# Out:
# Dependents: OK - only Yes/No -> {'No', 'Yes'}
# PhoneService: OK - only Yes/No -> {'No', 'Yes'}
# TechSupport: WARNING - extra values found -> {'No', 'Yes', 'No internet service'}
# StreamingTV: WARNING - extra values found -> {'No', 'Yes', 'No internet service'}
# StreamingMovies: WARNING - extra values found -> {'No', 'Yes', 'No internet service'}
# PaperlessBilling: OK - only Yes/No -> {'Yes', 'No'}
# Churn: OK - only Yes/No -> {'No', 'Yes'}

# %%
binary_cols = ['Dependents', 'PhoneService', 
                'PaperlessBilling', 'Churn']

for col in binary_cols:
    df_m[col] = df_m[col].map({'Yes': 1, 'No': 0})

df_m[binary_cols].head()
# Out:
#    Dependents  PhoneService  PaperlessBilling  Churn
# 0           0             0                 1      0
# 1           0             1                 0      0
# 2           0             1                 1      1
# 3           0             0                 0      0
# 4           0             1                 1      1

# %%
df_m
# Out:
#       customerID  is_female  SeniorCitizen  Partner_No  Dependents  tenure  \
# 0     7590-VHVEG          1              0           1           0       1
# 1     5575-GNVDE          0              0           1           0      34
# 2     3668-QPYBK          0              0           1           0       2
# 3     7795-CFOCW          0              0           1           0      45
# 4     9237-HQITU          1              0           1           0       2
# ...          ...        ...            ...         ...         ...     ...
# 7038  6840-RESVB          0              0           1           1      24
# 7039  2234-XADUH          1              0           1           1      72
# 7040  4801-JZAZL          1              0           1           1      11
# 7041  8361-LTMKD          0              1           1           0       4
# 7042  3186-AJIEK          0              0           1           0      66
#
# ...

# %%
df_m['TechSupport'].value_counts()
# Out:
# TechSupport
# No                     3473
# Yes                    2044
# No internet service    1526
# Name: count, dtype: int64

# %%
df_m = pd.get_dummies(df_m, columns=['TechSupport'], prefix='TechSupport')

# %%
df_m
# Out:
#       customerID  is_female  SeniorCitizen  Partner_No  Dependents  tenure  \
# 0     7590-VHVEG          1              0           1           0       1
# 1     5575-GNVDE          0              0           1           0      34
# 2     3668-QPYBK          0              0           1           0       2
# 3     7795-CFOCW          0              0           1           0      45
# 4     9237-HQITU          1              0           1           0       2
# ...          ...        ...            ...         ...         ...     ...
# 7038  6840-RESVB          0              0           1           1      24
# 7039  2234-XADUH          1              0           1           1      72
# 7040  4801-JZAZL          1              0           1           1      11
# 7041  8361-LTMKD          0              1           1           0       4
# 7042  3186-AJIEK          0              0           1           0      66
#
# ...

# %%
bool_cols = ['TechSupport_Yes', 'TechSupport_No internet service']  # adjust to your columns
df_m[bool_cols] = df_m[bool_cols].astype(int)

# %%
df_m
# Out:
#       customerID  is_female  SeniorCitizen  Partner_No  Dependents  tenure  \
# 0     7590-VHVEG          1              0           1           0       1
# 1     5575-GNVDE          0              0           1           0      34
# 2     3668-QPYBK          0              0           1           0       2
# 3     7795-CFOCW          0              0           1           0      45
# 4     9237-HQITU          1              0           1           0       2
# ...          ...        ...            ...         ...         ...     ...
# 7038  6840-RESVB          0              0           1           1      24
# 7039  2234-XADUH          1              0           1           1      72
# 7040  4801-JZAZL          1              0           1           1      11
# 7041  8361-LTMKD          0              1           1           0       4
# 7042  3186-AJIEK          0              0           1           0      66
#
# ...

# %%
df_m.drop('TechSupport_No', axis=1, inplace=True)

# %%
df_m
# Out:
#       customerID  is_female  SeniorCitizen  Partner_No  Dependents  tenure  \
# 0     7590-VHVEG          1              0           1           0       1
# 1     5575-GNVDE          0              0           1           0      34
# 2     3668-QPYBK          0              0           1           0       2
# 3     7795-CFOCW          0              0           1           0      45
# 4     9237-HQITU          1              0           1           0       2
# ...          ...        ...            ...         ...         ...     ...
# 7038  6840-RESVB          0              0           1           1      24
# 7039  2234-XADUH          1              0           1           1      72
# 7040  4801-JZAZL          1              0           1           1      11
# 7041  8361-LTMKD          0              1           1           0       4
# 7042  3186-AJIEK          0              0           1           0      66
#
# ...

# %%
df_m.value_counts()
# Out:
# customerID  is_female  SeniorCitizen  Partner_No  Dependents  tenure  PhoneService  MultipleLines     InternetService  OnlineSecurity       OnlineBackup         DeviceProtection     StreamingTV          StreamingMovies      Contract        PaperlessBilling  PaymentMethod              MonthlyCharges  TotalCharges  Churn  TechSupport_No internet service  TechSupport_Yes
# 0002-ORFBO  1          0              1           1           9       1             No                DSL              No                   Yes                  No                   Yes                  No                   One year        1                 Mailed check               65.60           593.3         0      0                                1                  1
# ...

# %%
df_m['StreamingTV'].value_counts()
# Out:
# StreamingTV
# No                     2810
# Yes                    2707
# No internet service    1526
# Name: count, dtype: int64

# %%
df_m = pd.get_dummies(df_m, columns=['StreamingTV'], prefix='StreamingTV')

# %%
bool_cols = ['StreamingTV_Yes', 'StreamingTV_No internet service']  # adjust to your columns
df_m[bool_cols] = df_m[bool_cols].astype(int)

# %%
df_m.drop('StreamingTV_No', axis=1, inplace=True)

# %%
df_m
# Out:
#       customerID  is_female  SeniorCitizen  Partner_No  Dependents  tenure  \
# 0     7590-VHVEG          1              0           1           0       1
# 1     5575-GNVDE          0              0           1           0      34
# 2     3668-QPYBK          0              0           1           0       2
# 3     7795-CFOCW          0              0           1           0      45
# 4     9237-HQITU          1              0           1           0       2
# ...          ...        ...            ...         ...         ...     ...
# 7038  6840-RESVB          0              0           1           1      24
# 7039  2234-XADUH          1              0           1           1      72
# 7040  4801-JZAZL          1              0           1           1      11
# 7041  8361-LTMKD          0              1           1           0       4
# 7042  3186-AJIEK          0              0           1           0      66
#
# ...

# %%
df_m['StreamingMovies'].value_counts()
# Out:
# StreamingMovies
# No                     2785
# Yes                    2732
# No internet service    1526
# Name: count, dtype: int64

# %%
df_m = pd.get_dummies(df_m, columns=['StreamingMovies'], prefix='StreamingMovies')

# %%
bool_cols = ['StreamingMovies_Yes', 'StreamingMovies_No internet service']  # adjust to your columns
df_m[bool_cols] = df_m[bool_cols].astype(int)

# %%
df_m.drop('StreamingMovies_No', axis=1, inplace=True)

# %%
df_m.head()
# Out:
#    customerID  is_female  SeniorCitizen  Partner_No  Dependents  tenure  \
# 0  7590-VHVEG          1              0           1           0       1
# 1  5575-GNVDE          0              0           1           0      34
# 2  3668-QPYBK          0              0           1           0       2
# 3  7795-CFOCW          0              0           1           0      45
# 4  9237-HQITU          1              0           1           0       2
#
#    PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0             0  No phone service             DSL             No  ...
# 1             1                No             DSL            Yes  ...
# 2             1                No             DSL            Yes  ...
# 3             0  No phone service             DSL            Yes  ...
# 4             1                No     Fiber optic             No  ...
#
#                PaymentMethod MonthlyCharges TotalCharges  Churn  \
# ...

# %%
non_numeric_cols = df_m.select_dtypes(exclude='number').columns

for col in non_numeric_cols:
    print(f"--- {col} ---")
    print(df[col].value_counts())
    print()
# Out:
# --- customerID ---
# customerID
# 7590-VHVEG    1
# 3791-LGQCY    1
# 6008-NAIXK    1
# 5956-YHHRX    1
# 5365-LLFYV    1
#              ..
# 9796-MVYXX    1
# 2637-FKFSY    1
# 1552-AAGRX    1
# 4304-TSPVK    1
# 3186-AJIEK    1
# Name: count, Length: 7043, dtype: int64
#
# --- MultipleLines ---
# MultipleLines
# No                  3390
# Yes                 2971
# No phone service     682
# Name: count, dtype: int64
#
# --- InternetService ---
# InternetService
# Fiber optic    3096
# DSL            2421
# No             1526
# Name: count, dtype: int64
#
# --- OnlineSecurity ---
# OnlineSecurity
# No                     3498
# Yes                    2019
# No internet service    1526
# Name: count, dtype: int64
#
# --- OnlineBackup ---
# OnlineBackup
# No                     3088
# Yes                    2429
# No internet service    1526
# Name: count, dtype: int64
#
# --- DeviceProtection ---
# DeviceProtection
# No                     3095
# Yes                    2422
# ...

# %%
for col in df_m.columns:
    print(f"--- {col} ({df_m[col].dtype}) ---")
    print(df_m[col].value_counts())
    print()
# Out:
# --- customerID (object) ---
# customerID
# 7590-VHVEG    1
# 3791-LGQCY    1
# 6008-NAIXK    1
# 5956-YHHRX    1
# 5365-LLFYV    1
#              ..
# 9796-MVYXX    1
# 2637-FKFSY    1
# 1552-AAGRX    1
# 4304-TSPVK    1
# 3186-AJIEK    1
# Name: count, Length: 7043, dtype: int64
#
# --- is_female (int64) ---
# is_female
# 0    3555
# 1    3488
# Name: count, dtype: int64
#
# --- SeniorCitizen (int64) ---
# SeniorCitizen
# 0    5901
# 1    1142
# Name: count, dtype: int64
#
# --- Partner_No (int64) ---
# Partner_No
# 1    7043
# Name: count, dtype: int64
#
# --- Dependents (int64) ---
# Dependents
# 0    4933
# 1    2110
# Name: count, dtype: int64
#
# --- tenure (int64) ---
# tenure
# 1     613
# 72    362
# 2     238
# 3     200
# 4     176
#      ...
# 28     57
# 39     56
# 44     51
# 36     50
# 0      11
# Name: count, Length: 73, dtype: int64
#
# --- PhoneService (int64) ---
# PhoneService
# 1    6361
# 0     682
# Name: count, dtype: int64
#
# ...

# %%
df['Partner'].value_counts()
# Out:
# Partner
# No     3641
# Yes    3402
# Name: count, dtype: int64

# %%
df['Partner_Yes'] = df['Partner'].map({'Yes': 1, 'No': 0})

# %%
df_m['Partner_No']=df['Partner_Yes']

# %%
for col in df_m.columns:
    print(f"--- {col} ({df_m[col].dtype}) ---")
    print(df_m[col].value_counts())
    print()
# Out:
# --- customerID (object) ---
# customerID
# 7590-VHVEG    1
# 3791-LGQCY    1
# 6008-NAIXK    1
# 5956-YHHRX    1
# 5365-LLFYV    1
#              ..
# 9796-MVYXX    1
# 2637-FKFSY    1
# 1552-AAGRX    1
# 4304-TSPVK    1
# 3186-AJIEK    1
# Name: count, Length: 7043, dtype: int64
#
# --- is_female (int64) ---
# is_female
# 0    3555
# 1    3488
# Name: count, dtype: int64
#
# --- SeniorCitizen (int64) ---
# SeniorCitizen
# 0    5901
# 1    1142
# Name: count, dtype: int64
#
# --- Partner_No (int64) ---
# Partner_No
# 0    3641
# 1    3402
# Name: count, dtype: int64
#
# --- Dependents (int64) ---
# Dependents
# 0    4933
# 1    2110
# Name: count, dtype: int64
#
# --- tenure (int64) ---
# tenure
# 1     613
# 72    362
# 2     238
# 3     200
# 4     176
#      ...
# 28     57
# 39     56
# 44     51
# 36     50
# 0      11
# Name: count, Length: 73, dtype: int64
#
# --- PhoneService (int64) ---
# PhoneService
# 1    6361
# 0     682
# Name: count, dtype: int64
#
# ...

# %%
cols_to_encode = ['InternetService', 'Contract', 'DeviceProtection', 'OnlineSecurity']

for col in cols_to_encode:
    dummies = pd.get_dummies(df_m[col], prefix=col, drop_first=True)
    dummies = dummies.astype(int)
    df_m = pd.concat([df_m, dummies], axis=1)
    df_m = df_m.drop(col, axis=1)

# %%
for col in df_m.columns:
    print(f"--- {col} ({df_m[col].dtype}) ---")
    print(df_m[col].value_counts())
    print()
# Out:
# --- customerID (object) ---
# customerID
# 7590-VHVEG    1
# 3791-LGQCY    1
# 6008-NAIXK    1
# 5956-YHHRX    1
# 5365-LLFYV    1
#              ..
# 9796-MVYXX    1
# 2637-FKFSY    1
# 1552-AAGRX    1
# 4304-TSPVK    1
# 3186-AJIEK    1
# Name: count, Length: 7043, dtype: int64
#
# --- is_female (int64) ---
# is_female
# 0    3555
# 1    3488
# Name: count, dtype: int64
#
# --- SeniorCitizen (int64) ---
# SeniorCitizen
# 0    5901
# 1    1142
# Name: count, dtype: int64
#
# --- Partner_No (int64) ---
# Partner_No
# 0    3641
# 1    3402
# Name: count, dtype: int64
#
# --- Dependents (int64) ---
# Dependents
# 0    4933
# 1    2110
# Name: count, dtype: int64
#
# --- tenure (int64) ---
# tenure
# 1     613
# 72    362
# 2     238
# 3     200
# 4     176
#      ...
# 28     57
# 39     56
# 44     51
# 36     50
# 0      11
# Name: count, Length: 73, dtype: int64
#
# --- PhoneService (int64) ---
# PhoneService
# 1    6361
# 0     682
# Name: count, dtype: int64
#
# ...

# %%
cols_to_encode = ['MultipleLines','OnlineBackup']

for col in cols_to_encode:
    dummies = pd.get_dummies(df_m[col], prefix=col, drop_first=True)
    dummies = dummies.astype(int)
    df_m = pd.concat([df_m, dummies], axis=1)
    df_m = df_m.drop(col, axis=1)

# %%
for col in df_m.columns:
    print(f"--- {col} ({df_m[col].dtype}) ---")
    print(df_m[col].value_counts())
    print()
# Out:
# --- customerID (object) ---
# customerID
# 7590-VHVEG    1
# 3791-LGQCY    1
# 6008-NAIXK    1
# 5956-YHHRX    1
# 5365-LLFYV    1
#              ..
# 9796-MVYXX    1
# 2637-FKFSY    1
# 1552-AAGRX    1
# 4304-TSPVK    1
# 3186-AJIEK    1
# Name: count, Length: 7043, dtype: int64
#
# --- is_female (int64) ---
# is_female
# 0    3555
# 1    3488
# Name: count, dtype: int64
#
# --- SeniorCitizen (int64) ---
# SeniorCitizen
# 0    5901
# 1    1142
# Name: count, dtype: int64
#
# --- Partner_No (int64) ---
# Partner_No
# 0    3641
# 1    3402
# Name: count, dtype: int64
#
# --- Dependents (int64) ---
# Dependents
# 0    4933
# 1    2110
# Name: count, dtype: int64
#
# --- tenure (int64) ---
# tenure
# 1     613
# 72    362
# 2     238
# 3     200
# 4     176
#      ...
# 28     57
# 39     56
# 44     51
# 36     50
# 0      11
# Name: count, Length: 73, dtype: int64
#
# --- PhoneService (int64) ---
# PhoneService
# 1    6361
# 0     682
# Name: count, dtype: int64
#
# ...

# %%
dummies = pd.get_dummies(df_m['PaymentMethod'], prefix='PaymentMethod', drop_first=True)
dummies = dummies.astype(int)
df_m = pd.concat([df_m, dummies], axis=1).drop('PaymentMethod', axis=1)

# %%
from sklearn.preprocessing import StandardScaler

cols_to_scale = ['tenure', 'MonthlyCharges', 'TotalCharges']

for col in cols_to_scale:
    df_m[col] = pd.to_numeric(df_m[col], errors='coerce')
    df_m[col] = df_m[col].fillna(df_m[col].median())

scaler = StandardScaler()
for col in cols_to_scale:
    df_m[col] = scaler.fit_transform(df_m[[col]])

# %%
dummies = pd.get_dummies(df_m['Contract'], prefix='Contract', drop_first=True)
dummies = dummies.astype(int)
df_m = pd.concat([df_m, dummies], axis=1).drop('Contract', axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
# --> 167 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
# --> 196 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7088 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# ...
